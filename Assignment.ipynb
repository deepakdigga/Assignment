# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Deepak Digga**
# Product associate at RND Apparels Pvt. Ltd.

# %% [markdown]
# *I am interested in data science because I wanna get into product management and i believe Data makes a huge difference in making informed decisions.*

# %% [markdown]
# ### Now the codes in next step will show simple calculations

# %%
2+2
# Out:
# 4

# %% [markdown]
# ### Following is the list of skills o good PM must have:

# %% [markdown]
# 1. UI/UX
# 2. Problem Solving
# 3. Marketing
# 4. data Analytics
# 5. Coomunication
# 6. ~~Management~~
